# %% [markdown]
# [YDATA-PROFILING](https://github.com/ydataai/ydata-profiling) - библиотека с открытым исходным кодом, которая создаёт подробный отчёт по данным.
#
# Установка:
#
# ```py
# pip install -U ydata-profiling
# pip install ipywidgets
# ```
#
# ```py
# from ydata_profiling import ProfileReport
# df = pd.read_csv('data/wine.csv')
#
# profile = ProfileReport(df, title='Pandas Profiling Report')
#
# profile
# ```
# >**Примечание.** Чтобы сохранить собственный отчёт в виде *HTML*-файла, вы можете воспользоваться методом `to_file()`, передав в него путь до файла, в который вы хотите сохранить результат:
# `profile.to_file("your_report.html")`

# %% [markdown]
# ---

# %% [markdown]
# [SWEETVIZ](https://github.com/fbdesignpro/sweetviz) - библиотека автоматического анализа с открытым исходным кодом. Её можно использовать для сравнения нескольких наборов данных и выводов по ним.
#
# Установка:
# ```PY
# pip install sweetviz
# ```
# ```py
# import pandas as pd
# import sweetviz as sv
#
# df = pd.read_csv('data/wine.csv')
#
# report = sv.analyze(df)
# report.show_html()
# ```

# %% [markdown]
# ---

# %% [markdown]
# `D-TALE` — это библиотека с открытым исходным кодом. *D-Tale* делает подробный разведывательный анализ набора данных. Интересная особенность: *библиотека предоставляет функцию экспорта кода для каждого графика или элемента анализа в отчёте.*
#
# Установка:
#
# `pip install dtale`
#
# ```PY
# d = dtale.show(df)
# d
# ```
